# %% [markdown]
# <a href="https://colab.research.google.com/github/Ganta-khethana/DS_S7_T18_AgriIntelligence/blob/main/Ds_week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# Sample dataset
df = pd.DataFrame({
    'Age': [25, 30, np.nan, 40, 35],
    'Department': ['HR', 'Finance', 'Finance', np.nan, 'IT']
})

# Display Original Dataset
print("Original Dataset (With Missing Values):")
print(df)

# Mean for numeric column
df['Age'] = df['Age'].fillna(df['Age'].mean())0

# Mode for categorical column
df['Department'] = df['Department'].fillna(df['Department'].mode()[0])

print("\nDataset After Imputation:")
print(df)
# Out:
# Original Dataset (With Missing Values):
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2   NaN    Finance
# 3  40.0        NaN
# 4  35.0         IT
#
# Dataset After Imputation:
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2  32.5    Finance
# 3  40.0    Finance
# 4  35.0         IT

# %%
#2. Forward/Backward Fill
import pandas as pd
import numpy as np
df = pd.DataFrame({
    'Age': [25, 30, np.nan, 40, 35],
    'Department': ['HR', 'Finance', 'Finance', np.nan, 'IT']
})
# Display Original Dataset
print("Original Dataset (With Missing Values):")
print(df)
#Forward Fill (use previous value)
df_ffill = df.copy()
df_ffill.ffill(inplace=True)
print(df_ffill)
#Backward Fill (use next value)
df_bfill = df.copy()
df_bfill.bfill(inplace=True)
print(df_bfill)
# Out:
# Original Dataset (With Missing Values):
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2   NaN    Finance
# 3  40.0        NaN
# 4  35.0         IT
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2  30.0    Finance
# 3  40.0    Finance
# 4  35.0         IT
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2  40.0    Finance
# 3  40.0         IT
# 4  35.0         IT

# %%
#3.a Deletion (drop rows or columns)
import pandas as pd
import numpy as np
df = pd.DataFrame({
    'Age': [25, 30, np.nan, 40, 35],
    'Department': ['HR', 'Finance', 'Finance', np.nan, 'IT']
})
# Display Original Dataset
print("Original Dataset")
print(df)

# Drop rows with missing values
df_drop_rows = df.dropna()
print("After dropping rows:\n", df_drop_rows)

# Drop columns with missing values
df_drop_cols = df.dropna(axis=1)
print("After dropping columns:\n",df_drop_cols)
# Out:
# Original Dataset
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2   NaN    Finance
# 3  40.0        NaN
# 4  35.0         IT
# After dropping rows:
#      Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 4  35.0         IT
# After dropping columns:
#  Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
#3.b Removing Duplicates (Exact Match Removal)
import pandas as pd

# Sample dataset with duplicates
df = pd.DataFrame({
    'ID': [1, 2, 2, 3, 4, 4],
    'Name': ['Alice', 'Bob', 'Bob', 'Charlie', 'David', 'David'],
    'Age': [25, 30, 30, 35, 40, 40]
})
print("Original Data:\n",df)
# Remove exact Duplicates
df_exact = df.drop_duplicates()
print("\nAfter Exact Match Removal:\n",df_exact)
# Out:
# Original Data:
#     ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 2   2      Bob   30
# 3   3  Charlie   35
# 4   4    David   40
# 5   4    David   40
#
# After Exact Match Removal:
#     ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 3   3  Charlie   35
# 4   4    David   40

# %%
#3.b Removing Duplicates (Subset-Based Removal)
import pandas as pd

# Sample dataset with duplicates
df = pd.DataFrame({
    'ID': [1, 2, 2, 3, 4, 4],
    'Name': ['Alice', 'Bob', 'Bob', 'Charlie', 'David', 'David'],
    'Age': [25, 30, 30, 35, 40, 40]
})
print("Original Data:\n",df)
#Removal duplicates based only on 'ID'
df_subset_id = df.drop_duplicates(subset=['ID'])
print("\nAfter Subset-Based Removal (ID):\n", df_subset_id)
#Remove duplicates based only on 'Name'
df_subset_name = df.drop_duplicates(subset=['Name'])
print("\nAfter Subset-Based Removal (Name):\n", df_subset_name)
# Out:
# Original Data:
#     ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 2   2      Bob   30
# 3   3  Charlie   35
# 4   4    David   40
# 5   4    David   40
#
# After Subset-Based Removal (ID):
#     ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 3   3  Charlie   35
# 4   4    David   40
#
# After Subset-Based Removal (Name):
#     ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 3   3  Charlie   35
# 4   4    David   40

# %%
#3.b Removing Duplicates (Correcting Inconsistent Formats)
#3.b.a Data Standarization (ISO 8601 format)

# Sample dataset with inconsistent data formats
df = pd.DataFrame({
    'Date': ['2025-01-05', '05/01/2025', 'Jan 5, 2025', '2025.01.05']
})
print("Original Data:\n", df)
# Convert all dates to stanadard ISO format (YYYY-MM-DD)
df['Date'] = pd.to_datetime(df['Date'], errors='coerce').dt.strftime('%Y-%m-%d')
print(df)
# Out:
# Original Data:
#            Date
# 0   2025-01-05
# 1   05/01/2025
# 2  Jan 5, 2025
# 3   2025.01.05
#          Date
# 0  2025-01-05
# 1         NaN
# 2         NaN
# 3         NaN

# %%
#3.b Removing Duplicates (Correcting Inconsistent Formats)
#3.b.b Case Normalization (lowercase / uppercase)

#Sample dataset with inconsistent text cases
df = pd.DataFrame({
    'Name': ['Alice','BOB', 'charlie', 'DAVID']
})
print("Original Data:\n",df)
#Convert all names to lowercase
df['Name_lower'] = df['Name'].str.lower()
#Convert all names to uppercase
df['Name_upper'] = df['Name'].str.upper()
print("\n", df)
# Out:
# Original Data:
#        Name
# 0    Alice
# 1      BOB
# 2  charlie
# 3    DAVID
#
#        Name Name_lower Name_upper
# 0    Alice      alice      ALICE
# 1      BOB        bob        BOB
# 2  charlie    charlie    CHARLIE
# 3    DAVID      david      DAVID
